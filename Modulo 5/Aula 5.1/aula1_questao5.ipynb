# %%
import emoji

# Lista de emojis disponíveis
emojis_disponiveis = {
    "❤️": ":red_heart:",
    "👍": ":thumbs_up:",
    "🤔": ":thinking_face:",
    "🥳": ":partying_face:"
}

# Exibe a lista de emojis disponíveis
print("Emojis disponíveis:")
for emj, cod in emojis_disponiveis.items():
    print(f"{emj} - {cod}")

# Solicita uma frase codificada ao usuário
frase_codificada = input("\nDigite uma frase e ela será emojizada:\n")

# Converte a frase codificada para a frase emojizada
frase_emojizada = emoji.emojize(frase_codificada, use_aliases=True)

# Exibe a frase emojizada
print("\nFrase emojizada:")
print(frase_emojizada)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-c8c272496f20> in <cell line: 1>()
# ----> 1 import emoji
#       2
#       3 # Lista de emojis disponíveis
#       4 emojis_disponiveis = {
#       5     "❤️": ":red_heart:",
#
# ModuleNotFoundError: No module named 'emoji'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
